# %%
import pandas as pd
df1 = pd.read_csv("/users/wyntoroffice/downloads/alcohol-available-for-consumption-year-ended-december-2017-zipped-csv-tables.csv")
print(df1)

color = ['blue']
df1['Series_title_1'].value_counts().plot(kind='hist',title= 'Volume of Alcohol Type per Capita since 1935 NZ',color=color)
(df1)

# X- axis represents type of alcohol indexed 
# Y- axis represents per capita volume of alcohol available
# Out:
#       Series_reference   Period  Data_value STATUS   UNITS  MAGNTUDE  \
# 0              ALCA.S1  1935.12   51.100000  FINAL  Litres         6
# 1              ALCA.S1  1936.12   58.700000  FINAL  Litres         6
# 2              ALCA.S1  1937.12   68.700000  FINAL  Litres         6
# 3              ALCA.S1  1938.12   78.100000  FINAL  Litres         6
# 4              ALCA.S1  1939.12   79.200000  FINAL  Litres         6
# 5              ALCA.S1  1940.12   83.300000  FINAL  Litres         6
# 6              ALCA.S1  1941.12         NaN  FINAL  Litres         6
# 7              ALCA.S1  1942.12         NaN  FINAL  Litres         6
# 8              ALCA.S1  1943.12         NaN  FINAL  Litres         6
# 9              ALCA.S1  1944.12         NaN  FINAL  Litres         6
# 10             ALCA.S1  1945.12         NaN  FINAL  Litres         6
# 11             ALCA.S1  1946.12  134.500000  FINAL  Litres         6
# 12             ALCA.S1  1947.12  137.700000  FINAL  Litres         6
# ...

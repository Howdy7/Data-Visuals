# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 100) 

# I expect population 2 to increase and overlap with population 2 as the sample size increases



plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 1000) 





plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 20) 


# I expect the population two to basically disappear in relation to population 1 on the graph


plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=14.796079832691666, pvalue=1.2820126357250037e-33)

# %%
pop1 = np.random.binomial(10, 0.3, 10000)
pop2 = np.random.binomial(10,0.5, 1000) 


# Expect higher p value to lead to great disparity


plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var = False))
plt.show()
# Out:
# Ttest_indResult(statistic=14.796079832691666, pvalue=1.2820126357250037e-33)

# %%
pop1 = np.random.binomial(10, 0.4, 10000)
pop2 = np.random.binomial(10,0.5, 1000) 





plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var = False))
plt.show()
# Out:
# Ttest_indResult(statistic=14.796079832691666, pvalue=1.2820126357250037e-33)

# %%
# Population 1 kept a similar form in representation, however a gap emerged in the center

# %%
pop1 = np.random.standard_gamma(10, 10000)
pop2 = np.random.standard_gamma(10, 1000) 





plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var = False))
plt.show()
# Out:
# Ttest_indResult(statistic=14.796079832691666, pvalue=1.2820126357250037e-33)

# %%
# The sample mean values accurately represent the population values as they

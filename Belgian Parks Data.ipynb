# %%
import pandas as pd
df1 = pd.read_csv("/users/wyntoroffice/downloads/park.csv")
print(df1)
colors = ['green','blue']
df1['TYPE'].value_counts().plot(kind='pie',title='Type of Parks',colors=colors)
plt.show(df1)
# Displays the two park categories in Belgium 
# Shows distribution of each park type
# Out:
#      OBJECTID                            NAAM       TYPE  \
# 0        6573                  HOF VAN LEYSEN       park
# 1        6574                      VINKENPARK  buurtpark
# 2        6575                     ROCKOXPLEIN  buurtpark
# 3        6576                   GLASGOWSTRAAT  buurtpark
# 4        6577                   ANTWERPSE ZOO       park
# 5        6578                  COLUMBIASTRAAT  buurtpark
# 6        6579             PATER STRACKESTRAAT  buurtpark
# 7        6580                   PLUVIERSTRAAT  buurtpark
# 8        6581                 VLAAMSHOOFDLAAN  buurtpark
# 9        6582                 HANEGRAEFSTRAAT  buurtpark
# 10       6583            AUGUST VERMEYLENLAAN  buurtpark
# 11       6584           TIJL UILENSPIEGELLAAN  buurtpark
# 12       6585                  SLACHTHUISLAAN  buurtpark
# 13       6586               PAUL VEKEMANSLAAN  buurtpark
# 14       6587                    DEN BOTANIEK       park
# ...

# %%
#

# %%
import pandas as pd
df1 = pd.read_csv("/users/wyntoroffice/downloads/well-being-gss16-well-being-measures-tables-csv.csv")
print(df1)

color = ['green','blue']
df1['Estimate'].value_counts().plot(kind='hist',title='CIB',color=color)
(df1)
# Out:
#      CACode VaCode  Estimate  LowerCIB  UpperCIB Flag
# 0      C01T   V01A      17.1      16.2      18.1  NaN
# 1      C01T   V01B      18.0      17.1      18.9  NaN
# 2      C01T   V01C      31.0      29.9      32.2  NaN
# 3      C01T   V01D      15.8      14.8      16.8  NaN
# 4      C01T   V01E      18.0      16.9      19.0  NaN
# 5      C01T   V02A      12.5      11.7      13.4  NaN
# 6      C01T   V02B      16.0      14.8      17.1  NaN
# 7      C01T   V02C      29.7      28.4      31.0  NaN
# 8      C01T   V02D      17.6      16.5      18.7  NaN
# 9      C01T   V02E      24.2      23.2      25.3  NaN
# 10     C01T   V03A      10.9      10.1      11.8  NaN
# 11     C01T   V03B      24.2      22.9      25.5  NaN
# 12     C01T   V03C      46.5      45.2      47.7  NaN
# 13     C01T   V03D      18.4      17.3      19.5  NaN
# 14     C01T   V04A      19.2      18.0      20.4  NaN
# 15     C01T   V04B      38.9      37.6      40.2  NaN
# ...

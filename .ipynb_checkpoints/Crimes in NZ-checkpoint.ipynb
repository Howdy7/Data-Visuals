# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd 
df1 = pd.read_csv("/users/wyntoroffice/downloads/analysis-public-place-assaults-sexual-assaults-and-robberies-2015-csv.csv")
print(df1)

color = ['Red']
df1['Victimisations_calendar_year_2015'].value_counts().plot(kind='hist',title='Crimes by Territorial Code',color=color)
plt.show(df1)

# Shows the concentration of crimes within ranges of territorial codes 
# Strong correlation in area codes within the first 75 (0-75)
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# 5         6               514101             Auckland Harbourside
# 6         7               524604                  Manukau Central
# 7         8               562800         Palmerston North Central
# 8         9               540410                           Kuirau
# 9        10               538201                 Tauranga Central
# 10       11               603100           Stuart St-Frederick St
# 11       12               521901                     Otahuhu West
# 12       13               582500                        Trafalgar
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
df1 = pd.read_csv("/users/wyntoroffice/downloads/business-price-indexes-march-2018-quarter.csv")
print(df1)

plt.plot([800,1000,1200])
plt.subplot(1200)
plt.plot(range(400))
plt.subplot(1996, facecolor='y') 

# Average Business price index for years after 1996 
# Strong continuation of trend (higher price correlates with  time prolonged since 1996)
# Out:
#       Series_reference   Period  Data_value STATUS  UNITS  \
# 0           CEPQ.S2371  1996.12       899.0  FINAL  Index
# 1           CEPQ.S2371  1997.03       884.0  FINAL  Index
# 2           CEPQ.S2371  1997.06       925.0  FINAL  Index
# 3           CEPQ.S2371  1997.09       932.0  FINAL  Index
# 4           CEPQ.S2371  1997.12       929.0  FINAL  Index
# 5           CEPQ.S2371  1998.03       940.0  FINAL  Index
# 6           CEPQ.S2371  1998.06       956.0  FINAL  Index
# 7           CEPQ.S2371  1998.09       958.0  FINAL  Index
# 8           CEPQ.S2371  1998.12       970.0  FINAL  Index
# 9           CEPQ.S2371  1999.03      1000.0  FINAL  Index
# 10          CEPQ.S2371  1999.06      1000.0  FINAL  Index
# 11          CEPQ.S2371  1999.09      1000.0  FINAL  Index
# 12          CEPQ.S2371  1999.12      1000.0  FINAL  Index
# 13          CEPQ.S2371  2000.03       949.0  FINAL  Index
# 14          CEPQ.S2371  2000.06       953.0  FINAL  Index
# ...
